# %% [markdown]
# Test referential critic and components

# %%
import os
import json
import numpy as np
os.chdir("D:\日本語の心配genAI")

import tiktoken
from shinpai_genai.critic.referential_critic import get_lesson_selector_chain, VarietyLessonSelectorChain
from shinpai_genai.critic.referential_critic import lesson_docs_from_ids
from shinpai_genai.critic.referential_critic import ReferentialCriticChain
from langchain.callbacks.manager import RunManager
from langchain.callbacks.base import BaseCallbackHandler

from typing import Any, Dict, List, Optional

# %%
def num_tokens_from_string(string: str, encoding_name: str = "cl100k_base") -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
# how long is the n4 lesson list
with open("./data/grammar_documents/n4_grammar/index_short.json", "r", encoding='utf-8') as f:
    # NOTE: read as string
    LESSON_LIST = f.read().encode('utf-8').decode('unicode_escape')

# %%
# wow that's longer than I expected..
    # maybe I'll just use 16k context
num_tokens_from_string(LESSON_LIST)
# Out:
# 3988

# %%
print(LESSON_LIST)
# Out:
# [
#     {
#         "id": 0,
#         "title": "あまり～ない (amari~nai)",
#         "short_description": "not very, not much"
#     },
#     {
#         "id": 1,
#         "title": "あとで (ato de)",
#         "short_description": "after, later"
#     },
#     {
#         "id": 2,
#         "title": "ば (ba)",
#         "short_description": "if… then"
#     },
#     {
#         "id": 3,
#         "title": "場合は (baai wa)",
#         "short_description": "in the event of"
#     },
#     {
#         "id": 4,
#         "title": "ばかり (bakari)",
#         "short_description": "only, nothing but"
#     },
#     {
#         "id": 5,
#         "title": "だけで (dake de)",
#         "short_description": "just by"
#     },
#     {
#         "id": 6,
#         "title": "だす (dasu)",
#         "short_description": "to suddenly begin, to suddenly appear"
#     },
#     {
#         "id": 7,
#         "title": "でも (demo)",
#         "short_description": "or something"
#     },
#     {
#         "id": 8,
#         "title": "でございます (de gozaimasu)",
#         "short_description": "to be (honorific)"
#     },
#     {
#         "id": 9,
#         "title": "がる (garu)",
#         "short_description": "to show signs of, to feel, to think"
#     },
#     {
#         "id": 10,
#         "title": "がする (ga suru)",
#         "short_description": "smell, hear, taste"
#     },
#     {
#         "id": 11,
#         "title": "ごろ (goro)",
#         "short_description": "around, about"
#     },
#     {
#         "id": 12,
#         "title": "ございます (gozaimasu)",
#         "short_description": "to be, to exist (honorific)"
#     },
#     {
#         "id": 13,
#         "title": "はじめる (hajimeru)",
#         "short_description": "to start, to begin to"
#     },
#     {
#         "id": 14,
#         "title": "はずだ (hazu da)",
#         "short_description": "it must be, it should be"
#     },
#     {
#         "id": 15,
#         "title": "はずがない (hazu ga nai)",
#         "short_description": "cannot be"
#     },
#     {
#         "id": 16,
#         "title": "ひつよう (hitsuyou)",
#         "short_description": "need, necessary"
#     },
#     {
#         "id": 17,
#         "title": "ひつようがある (hitsuyou ga aru)",
#         "short_description": "it is necessary to"
#     },
#     {
#         "id": 18,
#         "title": "ほしい (hoshii)",
#         "short_description": "to want something, to be in need of"
#     },
#     {
#         "id": 19,
#         "title": "いらっしゃる (irassharu)",
#         "short_description": "to be, to come, to go"
#     },
#     {
#         "id": 20,
#         "title": "いたす (itasu)",
#         "short_description": "to do (honorific)"
#     },
#     {
#         "id": 21,
#         "title": "じゃないか (janai ka)",
#         "short_description": "isn’t it"
#     },
#     {
#         "id": 22,
#         "title": "かどうか (ka dou ka)",
#         "short_description": "whether or not"
#     },
#     {
#         "id": 23,
#         "title": "かい (kai)",
#         "short_description": "(turns a sentence into a yes/no question)"
#     },
#     {
#         "id": 24,
#         "title": "かもしれない (kamoshirenai)",
#         "short_description": "might, maybe"
#     },
#     {
#         "id": 25,
#         "title": "かな (kana)",
#         "short_description": "I wonder"
#     },
#     {
#         "id": 26,
#         "title": "かた (kata)",
#         "short_description": "how to"
#     },
#     {
#         "id": 27,
#         "title": "かしら (kashira)",
#         "short_description": "I wonder"
#     },
#     {
#         "id": 28,
#         "title": "こと (koto)",
#         "short_description": "Verb nominalizer"
#     },
#     {
#         "id": 29,
#         "title": "ことができる (koto ga dekiru)",
#         "short_description": "can, be able to"
#     },
#     {
#         "id": 30,
#         "title": "ことになる (koto ni naru)",
#         "short_description": "it has been decided that"
#     },
#     {
#         "id": 31,
#         "title": "ことにする (koto ni suru)",
#         "short_description": "to decide on"
#     },
#     {
#         "id": 32,
#         "title": "までに (made ni)",
#         "short_description": "by, by the time"
#     },
#     {
#         "id": 33,
#         "title": "みたい (mitai)",
#         "short_description": "like, similar to, resembling"
#     },
#     {
#         "id": 34,
#         "title": "みたいに/みたいな (mitai ni/mitai na)",
#         "short_description": "like, similar to"
#     },
#     {
#         "id": 35,
#         "title": "など (nado)",
#         "short_description": "such as, things like"
#     },
#     {
#         "id": 36,
#         "title": "ながら (nagara)",
#         "short_description": "while, during, as"
#     },
#     {
#         "id": 37,
#         "title": "ないで (naide)",
#         "short_description": "without doing, don’t"
#     },
#     {
#         "id": 38,
#         "title": "なければいけない/なければならない (nakereba ikenai/nakereba naranai)",
#         "short_description": "must do, have to do"
#     },
#     {
#         "id": 39,
#         "title": "なくてはいけない/なくてはならない (nakutewa ikenai/nakutewa naranai)",
#         "short_description": "must do, have to do"
#     },
#     {
#         "id": 40,
#         "title": "なくてもいい (nakute mo ii)",
#         "short_description": "don’t have to"
#     },
#     {
#         "id": 41,
#         "title": "なら (nara)",
#         "short_description": "if, in case, as for"
#     },
#     {
#         "id": 42,
#         "title": "なさい (nasai)",
#         "short_description": "command (order somebody to do something)"
#     },
#     {
#         "id": 43,
#         "title": "なさる (nasaru)",
#         "short_description": "to do (honorific)"
#     },
#     {
#         "id": 44,
#         "title": "にくい (nikui)",
#         "short_description": "difficult to, hard to"
#     },
#     {
#         "id": 45,
#         "title": "のなかで (no naka de)",
#         "short_description": "in, among"
#     },
#     {
#         "id": 46,
#         "title": "のに(noni) – 1",
#         "short_description": "in order to"
#     },
#     {
#         "id": 47,
#         "title": "のに (noni) – 2",
#         "short_description": "although, in spite of, even though"
#     },
#     {
#         "id": 48,
#         "title": "のように / のような (no you ni/no you na)",
#         "short_description": "like, similar to"
#     },
#     {
#         "id": 49,
#         "title": "お～ください (o~kudasai)",
#         "short_description": "please do (honorific)"
#     },
#     {
#         "id": 50,
#         "title": "お～になる (o~ni naru)",
#         "short_description": "to do (honorific)"
#     },
#     {
#         "id": 51,
#         "title": "おきに (oki ni)",
#         "short_description": "repeated at intervals, every"
#     },
#     {
#         "id": 52,
#         "title": "おわる (owaru)",
#         "short_description": "to finish, to end"
#     },
#     {
#         "id": 53,
#         "title": "られる (rareru) – 1",
#         "short_description": "to be able to do something"
#     },
#     {
#         "id": 54,
#         "title": "られる (rareru) – 2",
#         "short_description": "(passive voice)"
#     },
#     {
#         "id": 55,
#         "title": "らしい (rashii)",
#         "short_description": "seems like"
#     },
#     {
#         "id": 56,
#         "title": "さ (sa)",
#         "short_description": "(nominalizer for adjectives)"
#     },
#     {
#         "id": 57,
#         "title": "させる (saseru)",
#         "short_description": "to make/let somebody do something"
#     },
#     {
#         "id": 58,
#         "title": "させられる (saserareru)",
#         "short_description": "to be made to do something"
#     },
#     {
#         "id": 59,
#         "title": "し (shi)",
#         "short_description": "and"
#     },
#     {
#         "id": 60,
#         "title": "しか～ない (shika~nai)",
#         "short_description": "only, nothing but"
#     },
#     {
#         "id": 61,
#         "title": "そんなに (sonna ni)",
#         "short_description": "so, so much, like that"
#     },
#     {
#         "id": 62,
#         "title": "それでも (sore demo)",
#         "short_description": "but still, and yet"
#     },
#     {
#         "id": 63,
#         "title": "そうに/そうな (sou ni/sou na)",
#         "short_description": "seem, look like"
#     },
#     {
#         "id": 64,
#         "title": "そうだ (sou da) – 1",
#         "short_description": "I heard that, it is said that"
#     },
#     {
#         "id": 65,
#         "title": "そうだ (sou da) – 2",
#         "short_description": "look like, appear, seem"
#     },
#     {
#         "id": 66,
#         "title": "すぎる (sugiru)",
#         "short_description": "too much"
#     },
#     {
#         "id": 67,
#         "title": "たばかり (ta bakari)",
#         "short_description": "just did, something just happened"
#     },
#     {
#         "id": 68,
#         "title": "たがる (tagaru)",
#         "short_description": "to want to"
#     },
#     {
#         "id": 69,
#         "title": "たら (tara)",
#         "short_description": "if, after, when"
#     },
#     {
#         "id": 70,
#         "title": "たらどう (tara dou)",
#         "short_description": "why don’t you"
#     },
#     {
#         "id": 71,
#         "title": "たり～たり (tari~tari)",
#         "short_description": "do such things like"
#     },
#     {
#         "id": 72,
#         "title": "たところ (ta tokoro)",
#         "short_description": "just finished doing, was just doing"
#     },
#     {
#         "id": 73,
#         "title": "てあげる (te ageru)",
#         "short_description": "to do something for someone"
#     },
#     {
#         "id": 74,
#         "title": "てある (te aru)",
#         "short_description": "something is/has been done"
#     },
#     {
#         "id": 75,
#         "title": "てほしい (te hoshii)",
#         "short_description": "I need you to"
#     },
#     {
#         "id": 76,
#         "title": "ていく (te iku)",
#         "short_description": "to go on, to start"
#     },
#     {
#         "id": 77,
#         "title": "ているところ (teiru tokoro)",
#         "short_description": "in the process of doing"
#     },
#     {
#         "id": 78,
#         "title": "ていただけませんか (te itadakemasen ka)",
#         "short_description": "could you please"
#     },
#     {
#         "id": 79,
#         "title": "てくれる (te kureru)",
#         "short_description": "to do something for someone"
#     },
#     {
#         "id": 80,
#         "title": "てくる (te kuru)",
#         "short_description": "to come to, to become, to continue"
#     },
#     {
#         "id": 81,
#         "title": "てみる (te miru)",
#         "short_description": "to try to"
#     },
#     {
#         "id": 82,
#         "title": "ても (temo)",
#         "short_description": "even if, even though"
#     },
#     {
#         "id": 83,
#         "title": "てもらう (te morau)",
#         "short_description": "to get somebody to do something"
#     },
#     {
#         "id": 84,
#         "title": "ておく (te oku)",
#         "short_description": "to do something in advance"
#     },
#     {
#         "id": 85,
#         "title": "てしまう (te shimau)",
#         "short_description": "to do something by accident, to finish completely"
#     },
#     {
#         "id": 86,
#         "title": "てすみません (te sumimasen)",
#         "short_description": "I’m sorry for"
#     },
#     {
#         "id": 87,
#         "title": "てよかった (te yokatta)",
#         "short_description": "I’m glad that"
#     },
#     {
#         "id": 88,
#         "title": "と (to)",
#         "short_description": "if, when, and"
#     },
#     {
#         "id": 89,
#         "title": "ということ (to iu koto)",
#         "short_description": "(changes a sentence or phrase into a Noun)"
#     },
#     {
#         "id": 90,
#         "title": "とか～とか (toka ~ toka)",
#         "short_description": "among other things, such as"
#     },
#     {
#         "id": 91,
#         "title": "とき (toki)",
#         "short_description": "when, at the time"
#     },
#     {
#         "id": 92,
#         "title": "ところ (tokoro)",
#         "short_description": "about to, on the verge of"
#     },
#     {
#         "id": 93,
#         "title": "とおもう (to omou)",
#         "short_description": "I think, you think"
#     },
#     {
#         "id": 94,
#         "title": "つづける (tsuzukeru)",
#         "short_description": "to continue"
#     },
#     {
#         "id": 95,
#         "title": "やすい (yasui)",
#         "short_description": "easy to, likely to"
#     },
#     {
#         "id": 96,
#         "title": "より (yori)",
#         "short_description": "than"
#     },
#     {
#         "id": 97,
#         "title": "よていだ (yotei da)",
#         "short_description": "plan to, intend to"
#     },
#     {
#         "id": 98,
#         "title": "ようだ (you da)",
#         "short_description": "it seems that, it appears that, it looks like"
#     },
#     {
#         "id": 99,
#         "title": "ように/ような (you ni/you na)",
#         "short_description": "as, like, just like"
#     },
#     {
#         "id": 100,
#         "title": "ようになる (you ni naru)",
#         "short_description": "to reach the point that"
#     },
#     {
#         "id": 101,
#         "title": "ようにする (you ni suru)",
#         "short_description": "to try to, to make sure that"
#     },
#     {
#         "id": 102,
#         "title": "ようとおもう (you to omou)",
#         "short_description": "I think I will"
#     },
#     {
#         "id": 103,
#         "title": "ぜんぜん (zenzen)",
#         "short_description": "(not) at all"
#     },
#     {
#         "id": 104,
#         "title": "Transitive & Intransitive Verbs",
#         "short_description": ""
#     },
#     {
#         "id": 105,
#         "title": "Volitional form",
#         "short_description": ""
#     }
# ]

# %%
print(len(json.loads(LESSON_LIST)))
# Out:
# 106

# %%
# exclude the last practice buddy message
    # this will be handled in get_conversation_string

samp_conversation_str = '''
STUDENT: こんにちは！今から日本語の練習します。
PRACTICE BUDDY: こんにちは！それは素晴らしいですね！日本語の練習にはどのようなことをしたいですか？文法や単語の練習、会話の練習、それとも他の何かですか？
STUDENT: 今日は土曜日だよ。たくさんねました。11時に起きました。
'''

# %%
lesson_selector_chain = get_lesson_selector_chain()

# %%
# MAYBE:
    # take two here, then add 1 randomly for some variety

# MAYBE:
    # shuffle the lesson_list everytime so that it doesn't bias towards the start?
    # this may be worth making a custom chain for
    # both of the above

# res = lesson_selector_chain.run(
#     {"conversation": samp_conversation_str}
# )
# print(res)

# %%
LESSON_LIST_DICTS = json.loads(LESSON_LIST)
print(LESSON_LIST_DICTS)
# Out:
# [{'id': 0, 'title': 'あまり～ない (amari~nai)', 'short_description': 'not very, not much'}, {'id': 1, 'title': 'あとで (ato de)', 'short_description': 'after, later'}, {'id': 2, 'title': 'ば (ba)', 'short_description': 'if… then'}, {'id': 3, 'title': '場合は (baai wa)', 'short_description': 'in the event of'}, {'id': 4, 'title': 'ばかり (bakari)', 'short_description': 'only, nothing but'}, {'id': 5, 'title': 'だけで (dake de)', 'short_description': 'just by'}, {'id': 6, 'title': 'だす (dasu)', 'short_description': 'to suddenly begin, to suddenly appear'}, {'id': 7, 'title': 'でも (demo)', 'short_description': 'or something'}, {'id': 8, 'title': 'でございます (de gozaimasu)', 'short_description': 'to be (honorific)'}, {'id': 9, 'title': 'がる (garu)', 'short_description': 'to show signs of, to feel, to think'}, {'id': 10, 'title': 'がする (ga suru)', 'short_description': 'smell, hear, taste'}, {'id': 11, 'title': 'ごろ (goro)', 'short_description': 'around, about'}, {'id': 12, 'title': 'ございます (gozaimasu)', 'short_description': 'to be, to exist (honorific)'}, {'id': 13, 'title': 'はじめる (hajimeru)', 'short_description': 'to start, to begin to'}, {'id': 14, 'title': 'はずだ (hazu da)', 'short_description': 'it must be, it should be'}, {'id': 15, 'title': 'はずがない (hazu ga nai)', 'short_description': 'cannot be'}, {'id': 16, 'title': 'ひつよう (hitsuyou)', 'short_description': 'need, necessary'}, {'id': 17, 'title': 'ひつようがある (hitsuyou ga aru)', 'short_description': 'it is necessary to'}, {'id': 18, 'title': 'ほしい (hoshii)', 'short_description': 'to want something, to be in need of'}, {'id': 19, 'title': 'いらっしゃる (irassharu)', 'short_description': 'to be, to\xa0come, to go'}, {'id': 20, 'title': 'いたす (itasu)', 'short_description': 'to do (honorific)'}, {'id': 21, 'title': 'じゃないか (janai ka)', 'short_description': 'isn’t it'}, {'id': 22, 'title': 'かどうか (ka dou ka)', 'short_description': 'whether or not'}, {'id': 23, 'title': 'かい (kai)', 'short_description': '(turns a sentence into a yes/no question)'}, {'id': 24, 'title': 'かもしれない (kamoshirenai)', 'short_description': 'might, maybe'}, {'id': 25, 'title': 'かな (kana)', 'short_description': 'I wonder'}, {'id': 26, 'title': 'かた (kata)', 'short_description': 'how to'}, {'id': 27, 'title': 'かしら (kashira)', 'short_description': 'I wonder'}, {'id': 28, 'title': 'こと (koto)', 'short_description': 'Verb nominalizer'}, {'id': 29, 'title': 'ことができる (koto ga dekiru)', 'short_description': 'can, be able to'}, {'id': 30, 'title': 'ことになる (koto ni naru)', 'short_description': 'it has been decided that'}, {'id': 31, 'title': 'ことにする (koto ni suru)', 'short_description': 'to decide on'}, {'id': 32, 'title': 'までに (made ni)', 'short_description': 'by, by the time'}, {'id': 33, 'title': 'みたい (mitai)', 'short_description': 'like, similar to, resembling'}, {'id': 34, 'title': 'みたいに/みたいな (mitai ni/mitai na)', 'short_description': 'like, similar to'}, {'id': 35, 'title': 'など (nado)', 'short_description': 'such as, things like'}, {'id': 36, 'title': 'ながら (nagara)', 'short_description': 'while, during, as'}, {'id': 37, 'title': 'ないで (naide)', 'short_description': 'without doing, don’t'}, {'id': 38, 'title': 'なければいけない/なければならない (nakereba ikenai/nakereba naranai)', 'short_description': 'must do, have to do'}, {'id': 39, 'title': 'なくてはいけない/なくてはならない (nakutewa ikenai/nakutewa naranai)', 'short_description': 'must do, have to do'}, {'id': 40, 'title': 'なくてもいい (nakute mo ii)', 'short_description': 'don’t have to'}, {'id': 41, 'title': 'なら (nara)', 'short_description': 'if, in case, as for'}, {'id': 42, 'title': 'なさい (nasai)', 'short_description': 'command (order somebody to do something)'}, {'id': 43, 'title': 'なさる (nasaru)', 'short_description': 'to do (honorific)'}, {'id': 44, 'title': 'にくい (nikui)', 'short_description': 'difficult to, hard to'}, {'id': 45, 'title': 'のなかで (no naka de)', 'short_description': 'in, among'}, {'id': 46, 'title': 'のに(noni) – 1', 'short_description': 'in order to'}, {'id': 47, 'title': 'のに (noni) – 2', 'short_description': 'although, in spite ...

# %%
# how to turn back to string
LESSON_LIST_STR = json.dumps(LESSON_LIST_DICTS, ensure_ascii=False)
print(LESSON_LIST_STR)
# Out:
# [{"id": 0, "title": "あまり～ない (amari~nai)", "short_description": "not very, not much"}, {"id": 1, "title": "あとで (ato de)", "short_description": "after, later"}, {"id": 2, "title": "ば (ba)", "short_description": "if… then"}, {"id": 3, "title": "場合は (baai wa)", "short_description": "in the event of"}, {"id": 4, "title": "ばかり (bakari)", "short_description": "only, nothing but"}, {"id": 5, "title": "だけで (dake de)", "short_description": "just by"}, {"id": 6, "title": "だす (dasu)", "short_description": "to suddenly begin, to suddenly appear"}, {"id": 7, "title": "でも (demo)", "short_description": "or something"}, {"id": 8, "title": "でございます (de gozaimasu)", "short_description": "to be (honorific)"}, {"id": 9, "title": "がる (garu)", "short_description": "to show signs of, to feel, to think"}, {"id": 10, "title": "がする (ga suru)", "short_description": "smell, hear, taste"}, {"id": 11, "title": "ごろ (goro)", "short_description": "around, about"}, {"id": 12, "title": "ございます (gozaimasu)", "short_description": "to be, to exist (honorific)"}, {"id": 13, "title": "はじめる (hajimeru)", "short_description": "to start, to begin to"}, {"id": 14, "title": "はずだ (hazu da)", "short_description": "it must be, it should be"}, {"id": 15, "title": "はずがない (hazu ga nai)", "short_description": "cannot be"}, {"id": 16, "title": "ひつよう (hitsuyou)", "short_description": "need, necessary"}, {"id": 17, "title": "ひつようがある (hitsuyou ga aru)", "short_description": "it is necessary to"}, {"id": 18, "title": "ほしい (hoshii)", "short_description": "to want something, to be in need of"}, {"id": 19, "title": "いらっしゃる (irassharu)", "short_description": "to be, to come, to go"}, {"id": 20, "title": "いたす (itasu)", "short_description": "to do (honorific)"}, {"id": 21, "title": "じゃないか (janai ka)", "short_description": "isn’t it"}, {"id": 22, "title": "かどうか (ka dou ka)", "short_description": "whether or not"}, {"id": 23, "title": "かい (kai)", "short_description": "(turns a sentence into a yes/no question)"}, {"id": 24, "title": "かもしれない (kamoshirenai)", "short_description": "might, maybe"}, {"id": 25, "title": "かな (kana)", "short_description": "I wonder"}, {"id": 26, "title": "かた (kata)", "short_description": "how to"}, {"id": 27, "title": "かしら (kashira)", "short_description": "I wonder"}, {"id": 28, "title": "こと (koto)", "short_description": "Verb nominalizer"}, {"id": 29, "title": "ことができる (koto ga dekiru)", "short_description": "can, be able to"}, {"id": 30, "title": "ことになる (koto ni naru)", "short_description": "it has been decided that"}, {"id": 31, "title": "ことにする (koto ni suru)", "short_description": "to decide on"}, {"id": 32, "title": "までに (made ni)", "short_description": "by, by the time"}, {"id": 33, "title": "みたい (mitai)", "short_description": "like, similar to, resembling"}, {"id": 34, "title": "みたいに/みたいな (mitai ni/mitai na)", "short_description": "like, similar to"}, {"id": 35, "title": "など (nado)", "short_description": "such as, things like"}, {"id": 36, "title": "ながら (nagara)", "short_description": "while, during, as"}, {"id": 37, "title": "ないで (naide)", "short_description": "without doing, don’t"}, {"id": 38, "title": "なければいけない/なければならない (nakereba ikenai/nakereba naranai)", "short_description": "must do, have to do"}, {"id": 39, "title": "なくてはいけない/なくてはならない (nakutewa ikenai/nakutewa naranai)", "short_description": "must do, have to do"}, {"id": 40, "title": "なくてもいい (nakute mo ii)", "short_description": "don’t have to"}, {"id": 41, "title": "なら (nara)", "short_description": "if, in case, as for"}, {"id": 42, "title": "なさい (nasai)", "short_description": "command (order somebody to do something)"}, {"id": 43, "title": "なさる (nasaru)", "short_description": "to do (honorific)"}, {"id": 44, "title": "にくい (nikui)", "short_description": "difficult to, hard to"}, {"id": 45, "title": "のなかで (no naka de)", "short_description": "in, among"}, {"id": 46, "title": "のに(noni) – 1", "short_description": "in order to"}, {"id": 47, "title": "のに (noni) – 2", "short_description": "although, in spite of ...

# %%
my_list = [1,2,3,4,5]

print(np.random.choice(my_list, size = 1, replace = False))
# Out:
# [5]

# %% [markdown]
# Test Variety Lesson Selector

# %%
lesson_selector_chain = VarietyLessonSelectorChain()

# %%
class PrintHandler(BaseCallbackHandler):

    def on_text(self, text: str, **kwargs):

        print(text)

print_handler = PrintHandler()

# %%
res = lesson_selector_chain.run(
    {
        "conversation": samp_conversation_str,
        "lesson_list": LESSON_LIST_DICTS,
    },
    callbacks = [print_handler],
)
print(res)
# Out:
# Prompt after formatting:
# System: You are an assistant to a student learning Japanese.
# A conversation will be provided between the student and the practice buddy.
#
# You will also be provided a list of lessons in a json-like format.
# Each lesson will have the keys: "id", "title" and "short_description".
#
# Your task is to select 2 lessons which could be highlighted when providing feedback to the student.
# Specify the lessons you selected by providing the ids in a list.
#
# Respond only with the list of ids. Don't add anything else to your response.
#
# Prioritize lessons which the student may have used wrongly.
# Otherwise, if the student use correct grammar,
# select lessons which could be used in alternate sentence constructions
# or for conveying similar ideas.
#
# Focus on the student's most recent response.
# Only refer to his previous messages if absolutely necessary.
#
# LESSON LIST:
# [{"id": 9, "title": "がる (garu)", "short_description": "to show signs of, to feel, to think"}, {"id": 16, "title": "ひつよう (hitsuyou)", "short_description": "need, necessary"}, {"id": 101, "title": "ようにする (you ni suru)", "short_description": "to try to, to make sure that"}, {"id": 12, "title": "ございます (gozaimasu)", "short_description": "to be, to exist (honorific)"}, {"id": 20, "title": "いたす (itasu)", "short_description": "to do (honorific)"}, {"id": 0, "title": "あまり～ない (amari~nai)", "short_description": "not very, not much"}, {"id": 30, "title": "ことになる (koto ni naru)", "short_description": "it has been decided that"}, {"id": 59, "title": "し (shi)", "short_description": "and"}, {"id": 61, "title": "そんなに (sonna ni)", "short_description": "so, so much, like that"}, {"id": 72, "title": "たところ (ta tokoro)", "short_description": "just finished doing, was just doing"}, {"id": 37, "title": "ないで (naide)", "short_description": "without doing, don’t"}, {"id": 94, "title": "つづける (tsuzukeru)", "short_description": "to continue"}, {"id": 80, "title": "てくる (te kuru)", "short_description": "to come to, to become, to continue"}, {"id": 35, "title": "など (nado)", "short_description": "such as, things like"}, {"id": 62, "title": "それでも (sore demo)", "short_description": "but still, and yet"}, {"id": 24, "title": "かもしれない (kamoshirenai)", "short_description": "might, maybe"}, {"id": 105, "title": "Volitional form", "short_description": ""}, {"id": 68, "title": "たがる (tagaru)", "short_description": "to want to"}, {"id": 97, "title": "よていだ (yotei da)", "short_description": "plan to, intend to"}, {"id": 26, "title": "かた (kata)", "short_description": "how to"}, {"id": 2, "title": "ば (ba)", "short_description": "if… then"}, {"id": 67, "title": "たばかり (ta bakari)", "short_description": "just did, something just happened"}, {"id": 83, "title": "てもらう (te morau)", "short_description": "to get somebody to do something"}, {"id": 90, "title": "とか～とか (toka ~ toka)", "short_description": "among other things, such as"}, {"id": 18, "title": "ほしい (hoshii)", "short_description": "to want something, to be in need of"}, {"id": 21, "title": "じゃないか (janai ka)", "short_description": "isn’t it"}, {"id": 8, "title": "でございます (de gozaimasu)", "short_description": "to be (honorific)"}, {"id": 4, "title": "ばかり (bakari)", "short_description": "only, nothing but"}, {"id": 64, "title": "そうだ (sou da) – 1", "short_description": "I heard that, it is said that"}, {"id": 50, "title": "お～になる (o~ni naru)", "short_description": "to do (honorific)"}, {"id": 60, "title": "しか～ない (shika~nai)", "short_description": "only, nothing but"}, {"id": 79, "title": "てくれる (te kureru)", "short_description": "to do something for someone"}, {"id": 14, "title": "はずだ (hazu da)", "short_description": "it must be, it should be"}, {"id": 85, "title": "てしまう (te shimau)", "short_description": "to do something by accident, to finish completely"}, {"id": 6, "title": "だす (dasu)", "short_description": "to suddenly begin, to suddenly appear"}, {"id": 42, "title": "なさい (nasai)", "short_description": "command (order somebody to do something)"}, {"id": 66, "title": "すぎる (sugiru)", "short_description": "too much"}, {"id": 10, "title": "がする (ga suru)", "short_description": "smell, hear, taste"}, {"id": 41, "title": "なら (nara)", "short_description": "if, in case, as for"}, {"id": 44, "title": "にくい (nikui)", "short_description": "difficult to, hard to"}, {"id": 43, "title": "なさる (nasaru)", "short_description": "to do (honorific)"}, {"id": 102, "title": "ようとおもう (you to omou)", "short_description": "I think I will"}, {"id": 19, "title": "いらっしゃる (irassharu)", "short_description": "to be, to come, to go"}, {"id": 5, "title": "だけで (dake de)", "short_description": "just by"}, {"id": 31, "title": "ことにする (koto ni suru)", "short_description": "to decide on"}, {"id": 1, "title": "あとで (ato de)", "short_description": "after, later"}, {"id": 46, "title": "のに(noni) – 1", "short_description": "in order to"}, {"id": 11, "title": "ごろ (goro)", "sho ...
# Human: Select lessons for the following conversation:
#
# STUDENT: こんにちは！今から日本語の練習します。
# PRACTICE BUDDY: こんにちは！それは素晴らしいですね！日本語の練習にはどのようなことをしたいですか？文法や単語の練習、会話の練習、それとも他の何かですか？
# STUDENT: 今日は土曜日だよ。たくさんねました。11時に起きました。
#
# Total number of lessons: 106
# Lessons selected by llm: [72, 103]
# Remaining after llm: 104
# Selected by random: [62]
# [72, 103, 62]

# %% [markdown]
# Test lesson_docs_from_ids

# %%
# %time
print(lesson_docs_from_ids([72, 103, 62]))
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# LESSON 1:
# Learn JLPT N4 Grammar: たところ (ta tokoro)
#
# July 18, 2015
#
#
# Learn Japanese N4 Grammar
#
# Click on image to view full size.
#
# Meaning:
#  just finished doing; was just doing
#
# Formation:
#
# Verb-casual, past + ところ
#
# Example sentences:
#
# There are 31 example sentences available for this grammar point.
#
# たった今、病院から出てきたところなんです。
# We just came from the hospital.
# tatta ima, byouin kara dete kita tokoro nan desu.
#
# 彼は十分ばかりまえに帰ってきたところです。
# He came back not more than ten minutes ago.
# kare wa juppun bakari mae ni kaette kita tokoro desu.
#
# どのみち、もうあの男には退屈していたところだしな。
# I was growing bored with that man, anyway.
# dono michi, mou ano otoko ni wa taikutsu shite ita tokoro da shi na.
#
# ずいぶん長くかかったのね。心配になっていたところよ。
# You were gone a long time. I was starting to worry.
# zuibun nagaku kakatta no ne. shinpai ni natte ita tokoro yo.
#
# その内容について話し合いたいと思っていたところだ。
# I’ve been wanting to discuss it with you.
# sono naiyou ni tsuite hanashiaitai to omotte ita tokoro da.
#
# Click here
#  to download JLPT N4 Grammar Audio Lesson Part 1 (free, MP3 file).
#
# Click here
#  to download JLPT N4 Grammar Audio Lesson Part 2 to Part 10 (requires paid membership).
#
# Click here
#  to download JLPT N4 Vocabulary Audio Lesson Part 1 (free, MP3 file).
#
# Click here
#  to download JLPT N4 Vocabulary Audio Lesson Part 2 to Part 12 (requires paid membership).
#
# 中国はビジネス界でやっと一定の信用がつきはじめたところだ。
# China is just now starting to develop a level of credibility in the business.
# chuugoku wa bijinesukai de yatto ittei no shin’you ga tsuki hajimeta tokoro da.
#
# 爆弾が爆発したところだ。
# The bomb just exploded.
# bakudan ga bakuhatsu shita tokoro da.
#
# あなたのことを話してたところだよ。
# We were talking about you.
# anata no koto o hanashiteta tokoro da yo.
#
# アメリカから日本に戻ったところです。
# I just returned to Japan from America.
# amerika kara nihon ni modotta tokoro desu.
#
# あなたを起こしにいこうと思ってたところだ。
# I was thinking of waking you up.
# anata o okoshi ni ikou to omotteta tokoro da.
#
# Click here
#  to download JLPT N4 Vocabulary Infographics Part 1 (free).
#
# Click here
#  to download JLPT N4 Vocabulary Infographics Part 2 to Part 4 (requires paid membership).
#
# 彼が何か飲み物を取りにいったところよ。
# He just went to get something to drink.
# kare ga nani ka nomimono o tori ni itta tokoro yo.
#
# LESSON 2:
# Learn JLPT N4 Grammar: 全然～ない (zenzen~nai)
#
# July 31, 2015
#
#
# Learn Japanese N4 Grammar
#
# Click on image to view full size.
#
# Meaning:
#  (not) at all
#
# Formation:
#
# 全然 + Verb-ないform
#
# Example sentences:
#
# There are 26 example sentences available for this grammar point.
#
# 脳は全然疲れを知らない。
# The brain is utterly tireless.
# nou wa zenzen tsukare o shiranai.
#
# 全然知りませんね！いつのことです？
# I had no idea of it! When did it happen?
# zenzen shirimasen ne. itsu no koto desu.
#
# 同感だよ。ぜんぜん、謎はないよ。
# I agree with you; there is no mystery whatever.
# doukan da yo. zenzen, nazo wa nai yo.
#
# 敵といわれた意味が全然わかりませんが？
# I don’t know quite what you mean by enemies?
# teki to iwareta imi ga zenzen wakarimasen ga.
#
# きみは記憶なんか全然喪失していない。そうだろ？
# I guess there’s nothing wrong with your memory.
# kimi wa kioku nanka zenzen soushitsu shite inai. sou darou.
#
# Click here
#  to download JLPT N4 Grammar Audio Lesson Part 1 (free, MP3 file).
#
# Click here
#  to download JLPT N4 Grammar Audio Lesson Part 2 to Part 10 (requires paid membership).
#
# Click here
#  to download JLPT N4 Vocabulary Audio Lesson Part 1 (free, MP3 file).
#
# Click here
#  to download JLPT N4 Vocabulary Audio Lesson Part 2 to Part 12 (requires paid membership).
#
# 彼女に対して何も文句はありません、全然ありません。
# I’ve nothing to complain about her—nothing at all.
# kanojo ni taishite nanimo monku wa arimasen, zenzen arimasen.
#
# 彼女もそれはよく知っていると思うのですが、全然気にもしませんね。
# I think she knows it, but she doesn’t care.
# kanojo mo sore wa yoku shitte iru to omou no desu ga, zenzen ki ni mo shimasen ne.
#
# 意識をとり戻すまでどのくらい時間がかかったのか全然わかりません。
# I don’t know how long it was before I regained my consciousness.
# ishiki o torimodosu made dono kurai jikan ga kakatta no ka zenzen wakarimasen.
#
# 外見は全然似ていないが、この二人はいずれも、ほかの人に同じような感じを抱かせる。
# The two men, totally unlike so far as physical resemblance went, produce a similar effect.
# gaiken wa zenzen nite inai ga, kono futari wa izure mo, hoka no hito ni onaji you na kanji o idakaseru.
#
# LESSON 3:
# Learn JLPT N4 Grammar: それでも (sore demo)
#
# October 8, 2015
#
#
# Learn Japanese N4 Grammar
#
# Meaning:
#  but still; and yet; even so
#
# Formation:
#
# Phrase 1 + それでも + Phrase 2
#
# Download JTest4You’s N4 grammar ebook (674 pages)
#
# Example sentences:
#
# 「三年間も彼女に会っていません。」「それでも君はその女と結婚しているんだよ。」
#
# “I haven’t seen her in three years.” “Still you are married to her.”
#
# sannenkan mo kanojo ni atte imasen. sore demo kimi wa sono onna to kekkon shite irun da yo.
#
# https://japanesetest4you.com/audio6/n4g-soredemo-01.mp3
#
#
#
# それでも彼女はわたしを愛してはいたのです。
#
# And yet she loved me.
#
# sore demo kanojo wa watashi o aishite wa ita no desu.
#
# https://japanesetest4you.com/audio6/n4g-soredemo-02.mp3
#
#
#
# ハルカは唇が震え目に涙がうかんだ。それでも、無理に快活さをよそおって、それを抑えておしゃべりをつづけた。
#
# Haruka’s lips trembled and the tears came to her eyes, but she hid these signs with a forced gayety and went on chattering.
#
# haruka wa kuchibiru ga furueme ni namida ga ukanda. sore demo, muri ni kaikatsu sa o yosootte, sore o osaete oshaberi o tsuzuketa.
#
# https://japanesetest4you.com/audio6/n4g-soredemo-03.mp3
#
#
#
# 彼女は食べることに集中しようとした。それでも手は震え、顔は怒りで火照りはじめた。
#
# She tried to concentrate on her food, but her hands shook and her face was starting to burn with anger.
#
# kanojo wa taberu koto ni shuuchuu shiyou to shita. sore demo te wa furue, kao wa ikari de hoteri hajimeta.
#
# https://japanesetest4you.com/audio6/n4g-soredemo-04.mp3
#
#
#
# それでも強情をはるようなら、こっちから引っぱりに行くから。
#
# If he resists, I shall come and fetch him.
#
# sore demo goujou o haru you nara, kocchi kara hippari ni iku kara.
#
# https://japanesetest4you.com/audio6/n4g-soredemo-05.mp3
#
#
#
# 皆、それでもまだ不思議そうにしているので、なぜこの試合をおもしろいと思ったのかも説明した。
#
# The bewilderment remained until I told them why the match interested me.
#
# mina, sore demo mada fushigisou ni shite iru node, naze kono shiai o omoshiroi to omotta no kamo setsumei shita.
#
# https://japanesetest4you.com/audio6/n4g-soredemo-06.mp3

# %% [markdown]
# Test Referential Critic

# %%
referential_critic = ReferentialCriticChain()

# %%
test_conversation = '''
STUDENT: こんにちは！今から日本語の練習します。
PRACTICE BUDDY: こんにちは！それは素晴らしいですね！日本語の練習にはどのようなことをしたいですか？文法や単語の練習、会話の練習、それとも他の何かですか？
STUDENT: 今日は土曜日だよ。たくさんねました。11時に起きました。
'''.strip()

# %%
critic_response = referential_critic.run(
    {"conversation": test_conversation},
)
print(critic_response)
# Out:
# The sentence "今日は土曜日だよ。たくさんねました。11時に起きました。" is grammatically correct and understandable. However, it seems like you wanted to express that you slept a lot today and woke up at 11 o'clock. To express this more naturally, you could use the grammar point "ことができる" to say "I was able to sleep a lot today" and "I was able to wake up at 11 o'clock."
#
# For example:
# - 今日はたくさん寝ることができました。11時に起きることができました。
#
# Using "ことができる" helps convey the idea of being able to do something, which fits well with your intention of expressing what you were able to do today. Keep up the good work!
